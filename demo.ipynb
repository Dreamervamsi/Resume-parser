# %%
import pymupdf4llm
#fa79c87fbae3f93a4947d88797bff24e03f8ac619ddd53b7
print(pymupdf4llm.to_markdown(r'C:\Users\kvams\OneDrive\Desktop\UPI Project\os.pdf',write_images=True,image_path="extracted_images"))
# Out:
# ![](extracted_images/os.pdf-0001-00.png)
